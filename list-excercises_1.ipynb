# %% [markdown]
# # แบบทดสอบการจัดการกับ List

# %%
นางสาว ญาณภา มงคล

# %%
lt = [1, 2, 3, 4, 5]

# %% [markdown]
# ## 1. เพิ่มข้อมูลเข้าไปใน list ทีละตัว
#
# 100, 200, 300, 400

# %%
lt.append(100)

# %%
lt.append(200)

# %%
lt.append(300)

# %%
lt.append(400)

# %%
print(lt)
# Out:
# [1, 2, 3, 4, 5, 100, 200, 300, 400]

# %% [markdown]
# ## 2. นำ List เพิ่มเข้าใน lt

# %%
sub = [6, 7, 8, 9, 10]

# %%
lt.append(sub)

# %%
lt
# Out:
# [1, 2, 3, 4, 5, 100, 200, 300, 400]

# %% [markdown]
# ## 3. เข้าถึงเข้ามูลตัวสุดท้ายภายใน list

# %%
lt[len(lt)-1]
# Out:
# [6, 7, 8, 9, 10]

# %% [markdown]
# ## 4. นำข้อมูลตัวสุดท้ายออกจาก list

# %%
print(lt.pop())

print(lt)
# Out:
# [6, 7, 8, 9, 10]
# [1, 2, 3, 4, 5, 100, 200, 300, 400]

# %% [markdown]
# ## 5. นำข้อมูลตัวที่ 5 ออกจาก list

# %%
del lt [4]

# %%
lt
# Out:
# [1, 2, 3, 4, 100, 200, 300, 400]

# %% [markdown]
# ## 6. เพิ่มคำว่า "Python" เข้าไปใน list ตำแหน่งที่ 3

# %%
lt.insert(2,"Python")

# %%
lt
# Out:
# [1, 2, 'Python', 3, 4, 100, 200, 300, 400]

# %% [markdown]
# ## 7. ลบข้อมูลในตำแหน่งที่ 6 ออกจาก list

# %%
del lt [5]

# %%
lt
# Out:
# [1, 2, 'Python', 3, 4, 200, 300, 400]

# %% [markdown]
# ## 8. แสดงจำนวนสมาชิกภายใน list

# %%
print(lt)
# Out:
# [1, 2, 'Python', 3, 4, 200, 300, 400]

# %% [markdown]
# ## 9. reverse list

# %%
lt[::-1]
# Out:
# [400, 300, 200, 4, 3, 'Python', 2, 1]

# %%
"python"[::-1]
# Out:
# 'nohtyp'

# %%
number = [1, 2, 3, 4, 5]
print (number[::-1])
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# ## 10. เคลียร์ list ให้เป็น list ว่าง

# %%
lt.clear()

# %%
lt
# Out:
# []
